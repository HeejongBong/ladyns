% %% [markdown]
% # Load data

% %%
data_dir = '.';
load(sprintf('%s/data_simulation_10.mat',data_dir))

% %%
data_0 = permute(data_0, [3 2 1]);
data_1 = permute(data_1, [3 2 1]);

% %%
size(data_0), size(data_1)
% Out:
% ans =
%
%         1000          25          50
%
%
% ans =
%
%         1000          25          50

% %%
num_trial = size(data_0, 1);
num_time = size(data_0, 3);

% %%
dat_0 = struct()
% Out:
% dat_0 =
%
%   struct with no fields.

% %%
dat_0.seq = struct( ...
    'trialId', num2cell(1:num_trial), ...
    'T', num2cell(zeros(1,num_trial) + num_time), ...
    'y', cellfun(@(c) squeeze(c), num2cell(data_0, [2 3])','UniformOutput',false) ...
)
% Out:
% dat_0 =
%
%   struct with fields:
%
%     seq: [1x1000 struct]

% %%
dat_1 = struct()
% Out:
% dat_1 =
%
%   struct with no fields.

% %%
dat_1.seq = struct( ...
    'trialId', num2cell(1:num_trial), ...
    'T', num2cell(zeros(1,num_trial) + num_time), ...
    'y', cellfun(@(c) squeeze(c), num2cell(data_1, [2 3])','UniformOutput',false) ...
)
% Out:
% dat_1 =
%
%   struct with fields:
%
%     seq: [1x1000 struct]

% %% [markdown]
% # Load external package

% %%
cd '../../../_external/NeuralTraj/'

% %%
run("startup.m")

% %% [markdown]
% ## Optional arguments

% %%
% Let's explicitly define all of the optional arguments, for 
% the sake of demonstration:
numFolds = 0;             % Number of cross-validation folds (0 means no cross-validation)
xDim = 3;
binWidth = 1;
kernSD = 5;

% %% [markdown]
% ## Fitting GPFA

% %%
result_0 = neuralTraj(1, dat_0, 'datFormat', 'seq', 'method', 'gpfa', ...
           'xDims', xDim, 'numFolds', numFolds, 'parallelize', false, ...,
           'binWdith', binWidth, 'kernSDList', kernSD, 'startEps', 0.8);
% Out:
% ---------------------------------------
% Using existing directory mat_results/run001...
%
% ===== Training on all data =====
% mat_results/run001/gpfa_xDim03 already exists.  Skipping...

% %%
[estParams_0, seqTrain_0] = postprocess(result_0, 'kernSD', kernSD);

% %%
result_1 = neuralTraj(2, dat_1, 'datFormat', 'seq', 'method', 'gpfa', ...
           'xDims', xDim, 'numFolds', numFolds, 'parallelize', false, ...,
           'binWdith', binWidth, 'kernSDList', kernSD, 'startEps', 0.8);
% Out:
% ---------------------------------------
% Using existing directory mat_results/run002...
%
% ===== Training on all data =====
% mat_results/run002/gpfa_xDim03 already exists.  Skipping...

% %%
[estParams_1, seqTrain_1] = postprocess(result_1, 'kernSD', kernSD);

% %% [markdown]
% # results

% %%
latent_0 = cat(3,seqTrain_0.xsm);
latent_1 = cat(3,seqTrain_1.xsm);

% %%
%plot -s 1200,1200
tcl = tiledlayout(3,3);
for i = 1:3
    for j = 1:3
        nexttile()
        latent_sigma = cov(squeeze(cat(2,latent_0(i,:,:),latent_1(j,:,:)))');
        imagesc(abs(latent_sigma(1:num_time,num_time+1:2*num_time)))
        axis square
        caxis([0 0.35])
        xlabel('time at region 2')
        ylabel('time at region 1')
    end
end
cb = colorbar(); 
cb.Layout.Tile = 'east'
% Out:
% cb =
%
%   ColorBar with properties:
%
%     Location: 'layout'
%       Limits: [0 0.3500]
%     FontSize: 9
%     Position: [0.9007 0.1100 0.0214 0.8150]
%        Units: 'normalized'
%
%   Use GET to show all properties

% %%
%plot -s 1500,400
for i = 1:3
    subplot(1,3,i)
    imagesc(abs(reshape(estParams_0.C(:,i),5,5)))
end

% %%
%plot -s 1500,400
for i = 1:3
    subplot(1,3,i)
    imagesc(abs(reshape(estParams_1.C(:,i),5,5)))
end

% %%
C_0 = estParams_0.C;
C_1 = estParams_1.C;
save(sprintf('%s/result_simulation_10_GPFA.mat', data_dir), 'latent_0', 'latent_1', 'C_0', 'C_1')
